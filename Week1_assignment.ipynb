# %% [markdown]
# <a href="https://colab.research.google.com/github/dzankavic10-max/CodeAlpha_IrisFlowerClassification/blob/main/Week1_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This code creates five variables with different data types to describe me.

name = "Emmanuel Dzanka"      # String
age = 21                      # Integer
height = 1.86                # Float
is_student = True             # Boolean
school = "University of Cape Coast"  # String

# %%
# This code prints a personal introduction using an f-string.

print(f"Hello! My name is {name}. I am {age} years old. "
      f"I study at {school}. My height is {height} meters. "
      f"Student status: {is_student}.")
# Out:
# Hello! My name is Emmanuel Dzanka. I am 21 years old. I study at University of Cape Coast. My height is 1.86 meters. Student status: True.

# %%
# This code calculates the weekly cost of transportation.

daily_transport = 20      # GHS per day
days = 5
weekly_transport = daily_transport * days
extra_cost = 15
total_cost = weekly_transport + extra_cost
average_per_day = total_cost / days

print("Weekly Transport Cost")
print("Weekly transport:", weekly_transport, "GHS")
print("Total cost:", total_cost, "GHS")
print("Average per day:", average_per_day, "GHS")
# Out:
# Weekly Transport Cost
# Weekly transport: 100 GHS
# Total cost: 115 GHS
# Average per day: 23.0 GHS
